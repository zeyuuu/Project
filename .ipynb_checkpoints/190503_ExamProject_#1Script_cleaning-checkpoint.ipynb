# %% [markdown]
# # Exam Project: The formation of ISIS' Social Media Network

# %% [markdown]
# Group members: Zeyu Zhao, Helge Zille, Edith Zink, Sina Smid

# %%
import os
import requests

import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# **Data import:**
# - Dataset is downloaded from Kaggle (https://www.kaggle.com/fifthtribe/how-isis-uses-twitter)
# - Some of text is in Arabic, this will be ignored (encoding = 'Latin-1') and only Latin (English?) text will be used in the analysis

# %%
data = pd.read_csv('tweets.csv', encoding='Latin-1')
data.head(10)
# Out:
#                    name        username  \
# 0    Plea Of the Ummah!  pleaoftheummah
# 1           Dragontail2     saifulakhir
# 2   Obi-Wan Al Coconuty   Uncle_SamCoco
# 3      War BreakingNews        warrnews
# 4  ???? ????? ??? ?????   Uncle_SamCoco
# 5  ???? ????? ??? ?????   Uncle_SamCoco
# 6          ????? ??????   Uncle_SamCoco
# 7              Maghrebi      MaghrebiQM
# 8  ???? ????? ??? ?????   Uncle_SamCoco
# 9  ???? ????? ??? ?????   Uncle_SamCoco
#
#                                          description               location  \
# 0  Plea of the Ummah!\nUmmathuge Aadheys!\nA Camp...                    NaN
# 1                           hater please dont follow  Singaparna, Indonesia
# 2  Here to defend the  American freedom and also ...          United States
# 3       we provide fresh news from every battlefield                  world
# 4  Here to defend the  American freedom and also ...             Texas, USA
# 5  Here to defend the  American freedom and also ...          United States
# 6  Here to defend the  American freedom and also ...             Texas, USA
# 7  A Moroccan engineer in nanotechnology commenti...                    NaN
# 8  Here to defend the  American freedom and also ...          United States
# 9  Here to defend the  American freedom and also ...             Texas, USA
#
#    followers  numberstatuses             time  \
# 0         92            1021  3/27/2016 13:55
# 1         35             243   4/15/2016 9:05
# 2       1273            1820  1/31/2016 15:30
# 3       7293            6756    3/3/2016 6:16
# 4       1543            3730  3/11/2016 17:21
# 5       1376            2852  2/18/2016 21:19
# 6       1772            5304   4/14/2016 5:59
# 7        762              61  1/31/2016 11:49
# 8       1465            3198  2/25/2016 21:03
# 9       1543            3730   3/9/2016 21:56
#
#                                               tweets
# 0  - Breaking! According to Amaq, pro Islamic Sta...
# 1  " Ingatlah, hanyalah milikNyalah penciptaan da...
# 2  " La véritable histoire ...." surement un bon ...
# 3  " We commited hundreds of thousands of troops ...
# 4  " Win the heart of the people first " ??\n\n#S...
# 5  "....Le rêve américain ne la toujours pas qui...
# 6  "29 German soldiers left to join ISIS; army ma...
# 7  "30 killed, 40 injured after a bombing in "Say...
# 8  "A Kurdish Convergence in Syria"\n\nhttps://t....
# 9  "Abbas to Biden: Palestinian State Key to Beat...

# %% [markdown]
# **Data cleaning:**
# - Prepare `tweets` column for text analysis

# %%
data.dtypes
# Out:
# name              object
# username          object
# description       object
# location          object
# followers          int64
# numberstatuses     int64
# time              object
# tweets            object
# dtype: object

# %%
# time as datetime
data['time'] = pd.to_datetime(data.time)
data.head()
# Out:
#                    name        username  \
# 0    Plea Of the Ummah!  pleaoftheummah
# 1           Dragontail2     saifulakhir
# 2   Obi-Wan Al Coconuty   Uncle_SamCoco
# 3      War BreakingNews        warrnews
# 4  ???? ????? ??? ?????   Uncle_SamCoco
#
#                                          description               location  \
# 0  Plea of the Ummah!\nUmmathuge Aadheys!\nA Camp...                    NaN
# 1                           hater please dont follow  Singaparna, Indonesia
# 2  Here to defend the  American freedom and also ...          United States
# 3       we provide fresh news from every battlefield                  world
# 4  Here to defend the  American freedom and also ...             Texas, USA
#
#    followers  numberstatuses                time  \
# 0         92            1021 2016-03-27 13:55:00
# 1         35             243 2016-04-15 09:05:00
# 2       1273            1820 2016-01-31 15:30:00
# 3       7293            6756 2016-03-03 06:16:00
# 4       1543            3730 2016-03-11 17:21:00
#
#                                               tweets
# 0  - Breaking! According to Amaq, pro Islamic Sta...
# 1  " Ingatlah, hanyalah milikNyalah penciptaan da...
# 2  " La véritable histoire ...." surement un bon ...
# 3  " We commited hundreds of thousands of troops ...
# 4  " Win the heart of the people first " ??\n\n#S...

# %%
# Remove everything after @ and https (we could also try to delete this here instead of later)

# %%
# Tokenize sentences into words: split into words
data['tweets_rec'] = data.tweets.str.strip().str.split('[\W_]+')
data.head()
# Out:
#                    name        username  \
# 0    Plea Of the Ummah!  pleaoftheummah
# 1           Dragontail2     saifulakhir
# 2   Obi-Wan Al Coconuty   Uncle_SamCoco
# 3      War BreakingNews        warrnews
# 4  ???? ????? ??? ?????   Uncle_SamCoco
#
#                                          description               location  \
# 0  Plea of the Ummah!\nUmmathuge Aadheys!\nA Camp...                    NaN
# 1                           hater please dont follow  Singaparna, Indonesia
# 2  Here to defend the  American freedom and also ...          United States
# 3       we provide fresh news from every battlefield                  world
# 4  Here to defend the  American freedom and also ...             Texas, USA
#
#    followers  numberstatuses                time  \
# 0         92            1021 2016-03-27 13:55:00
# 1         35             243 2016-04-15 09:05:00
# 2       1273            1820 2016-01-31 15:30:00
# 3       7293            6756 2016-03-03 06:16:00
# 4       1543            3730 2016-03-11 17:21:00
#
#                                               tweets  \
# 0  - Breaking! According to Amaq, pro Islamic Sta...
# 1  " Ingatlah, hanyalah milikNyalah penciptaan da...
# 2  " La véritable histoire ...." surement un bon ...
# 3  " We commited hundreds of thousands of troops ...
# 4  " Win the heart of the people first " ??\n\n#S...
#
#                                           tweets_rec
# 0  [, Breaking, According, to, Amaq, pro, Islamic...
# 1  [, Ingatlah, hanyalah, milikNyalah, penciptaan...
# 2  [, La, véritable, histoire, surement, un, bon,...
# 3  [, We, commited, hundreds, of, thousands, of, ...
# 4  [, Win, the, heart, of, the, people, first, Sa...

# %%
# Break words into different rows, by username
rows = list()
for row in data[['username', 'tweets_rec']].iterrows():
    r = row[1]
    for word in r.tweets_rec:
        rows.append((r.username, word))

tweets_words = pd.DataFrame(rows, columns=['username', 'word'])
tweets_words.head(20)
# Out:
#           username       word
# 0   pleaoftheummah
# 1   pleaoftheummah   Breaking
# 2   pleaoftheummah  According
# 3   pleaoftheummah         to
# 4   pleaoftheummah       Amaq
# 5   pleaoftheummah        pro
# 6   pleaoftheummah    Islamic
# 7   pleaoftheummah      State
# 8   pleaoftheummah      media
# 9   pleaoftheummah        the
# 10  pleaoftheummah     battle
# 11  pleaoftheummah         of
# 12  pleaoftheummah    Palmyra
# 13  pleaoftheummah         is
# 14  pleaoftheummah      still
# 15  pleaoftheummah         in
# 16  pleaoftheummah        the
# 17  pleaoftheummah  outskirts
# 18  pleaoftheummah         of
# 19  pleaoftheummah        the

# %%
# Removing empty cells
tweets_words = tweets_words[tweets_words.word.str.len() > 0]
tweets_words.head()
# Out:
#          username       word
# 1  pleaoftheummah   Breaking
# 2  pleaoftheummah  According
# 3  pleaoftheummah         to
# 4  pleaoftheummah       Amaq
# 5  pleaoftheummah        pro

# %%
# lower case words
tweets_words['word'] = tweets_words.word.str.lower()
tweets_words.head(100)
# Note: we still need to remove https and @, https is included as: 1st word) https, 2nd word) t, 3rd word) co (see below as example for row 20-22)
# Out:
#            username         word
# 1    pleaoftheummah     breaking
# 2    pleaoftheummah    according
# 3    pleaoftheummah           to
# 4    pleaoftheummah         amaq
# 5    pleaoftheummah          pro
# 6    pleaoftheummah      islamic
# 7    pleaoftheummah        state
# 8    pleaoftheummah        media
# 9    pleaoftheummah          the
# 10   pleaoftheummah       battle
# 11   pleaoftheummah           of
# 12   pleaoftheummah      palmyra
# 13   pleaoftheummah           is
# 14   pleaoftheummah        still
# 15   pleaoftheummah           in
# 16   pleaoftheummah          the
# 17   pleaoftheummah    outskirts
# 18   pleaoftheummah           of
# 19   pleaoftheummah          the
# 20   pleaoftheummah        https
# 21   pleaoftheummah            t
# 22   pleaoftheummah           co
# 23   pleaoftheummah   afzaskrbuf
# 25      saifulakhir     ingatlah
# 26      saifulakhir     hanyalah
# 27      saifulakhir  miliknyalah
# 28      saifulakhir   penciptaan
# 29      saifulakhir          dan
# 30      saifulakhir     perintah
# 31      saifulakhir           qs
# ..              ...          ...
# 75         warrnews        https
# 76         warrnews            t
# 77         warrnews           co
# 78         warrnews   aysc4a7ajp
# 80    Uncle_SamCoco          win
# 81    Uncle_SamCoco          the
# 82    Uncle_SamCoco        heart
# 83    Uncle_SamCoco           of
# 84    Uncle_SamCoco          the
# 85    Uncle_SamCoco       people
# 86    Uncle_SamCoco        first
# 87    Uncle_SamCoco         save
# 88    Uncle_SamCoco         fiqh
# 89    Uncle_SamCoco         waqi
# 90    Uncle_SamCoco        https
# 91    Uncle_SamCoco            t
# 92    Uncle_SamCoco           co
# 93    Uncle_SamCoco   56f8m2lovr
# 95    Uncle_SamCoco           le
# 96    Uncle_SamCoco         rêve
# 97    Uncle_SamCoco    américain
# 98    Uncle_SamCoco           ne
# 99    Uncle_SamCoco            l
# 100   Uncle_SamCoco            a
# 101   Uncle_SamCoco     toujours
# 102   Uncle_SamCoco          pas
# 103   Uncle_SamCoco       quitté
# 104   Uncle_SamCoco          fin
# 106   Uncle_SamCoco           29
# 107   Uncle_SamCoco       german
#
# [100 rows x 2 columns]

# %%
# dropping https and t, co
tweets_words.drop(['https', 't', 'co']) 
tweets_words.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-cb7d8478ad01> in <module>
#       1 # dropping https and t, co
# ----> 2 tweets_words.drop(['https', 't', 'co'])
#       3 tweets_words.head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['https' 't' 'co'] not found in axis"

# %% [markdown]
# **Note:** In the next part, I played around with the data to see what is possible using a blogpost online: https://sigdelta.com/blog/text-analysis-in-pandas/, which uses a TF-IDF method

# %%
counts = tweets_words.groupby('username')\
    .word.value_counts()\
    .to_frame()\
    .rename(columns={'word':'n_w'})
counts.head()
# Out:
#                       n_w
# username  word
# 04_8_1437 https        48
#           t            47
#           co           46
#           amaqagency   43
#           of           29

# %%
def pretty_plot_top_n(series, top_n=5, index_level=0):
    r = series\
    .groupby(level=index_level)\
    .nlargest(top_n)\
    .reset_index(level=index_level, drop=True)
    r.plot.bar()
    return r.to_frame()

pretty_plot_top_n(counts['n_w'])
# Out:
#                          n_w
# username     word
# 04_8_1437    https        48
#              t            47
#              co           46
#              amaqagency   43
#              of           29
# 06230550_IS  https        56
#              t            55
#              the          53
#              co           51
#              rt           45
# 1515Ummah    rt           58
#              the          51
#              https        47
#              in           45
#              t            38
# 1Dawlah_III  co          184
#              https       184
#              t           184
#              of          110
#              the          95
# 432Mryam     t            34
#              co           31
#              https        30
#              you          20
#              khair        14
# ALK___226    co           37
#              https        37
#              t            37
#              amaqagency    6
#              of            6
# ...                      ...
# war_analysis rt           80
#              t            46
#              https        43
#              the          41
#              in           38
# warreporter2 the         150
#              rt          115
#              https        95
#              of           88
#              t            83
# warrnews     https       889
#              t           838
#              co          790
#              in          653
#              rt          462
# wayf44rerr   https       197
#              t           197
#              co          168
#              of          142
#              in          130
# wayff44rer   of           10
#              the          10
#              t             8
#              co            7
#              https         7
# wayyf44rer   in           30
#              t            30
#              https        29
#              co           28
#              of           28
#
# [560 rows x 1 columns]

# %%
word_sum = counts.groupby(level=0)\
    .sum()\
    .rename(columns={'n_w': 'n_d'})
word_sum
# Out:
#                    n_d
# username
# 04_8_1437          870
# 06230550_IS       1221
# 1515Ummah         1703
# 1Dawlah_III       1793
# 432Mryam           658
# ALK___226          293
# Abdul__05           31
# AbdusMujahid149    639
# AbuLaythAlHindi    206
# AbuMusab_110      1582
# AbuNaseeha_03     1753
# Abu_Azzzam25      2168
# Abu_Ibn_Taha       411
# Afriqqiya_252      155
# Al_Battar_Engl    1808
# Alwala_bara       1411
# AsimAbuMerjem     4404
# Bajwa47online     1676
# BaqiyaIs          1417
# Baqiyah_Khilafa   1181
# Battar_English    1847
# BilalIbnRabah1     739
# CXaafada2         2409
# DabiqsweetsMan     223
# DawlaWitness11    1121
# Dieinurage308      200
# EPlC24            1594
# FidaeeFulaani     2347
# Fidaee_Fulaani    5596
# Freedom_speech2   1702
# ...                ...
# grezz10            702
# ismailmahsud      5987
# kIakishini5        477
# k_kid04            706
# klakishinki       2019
# ks48a174031        121
# lNSlDEWAR         2894
# maisaraghereeb    1861
# melvynlion        5448
# mobi_ayubi       20711
# moustiklash       1799
# murasil1          3428
# mustafaklash56     417
# mustaklash         360
# newerajihadi61      68
# nvor85j           1429
# pleaoftheummah    3996
# ro34th            5404
# safiyaimback      2478
# saifulakhir       1525
# sonofshishan       810
# squadsquaaaaad     757
# st3erer           1682
# thefIamesofhaqq   1741
# war_analysis      1737
# warreporter2      3516
# warrnews         19244
# wayf44rerr        5840
# wayff44rer         215
# wayyf44rer        1030
#
# [112 rows x 1 columns]

# %%
tf = counts.join(word_sum)

tf['tf'] = tf.n_w/tf.n_d

tf.head()
# Out:
#                       n_w  n_d        tf
# username  word
# 04_8_1437 https        48  870  0.055172
#           t            47  870  0.054023
#           co           46  870  0.052874
#           amaqagency   43  870  0.049425
#           of           29  870  0.033333

# %%
pretty_plot_top_n(tf['tf'])
# Out:
#                                tf
# username     word
# 04_8_1437    https       0.055172
#              t           0.054023
#              co          0.052874
#              amaqagency  0.049425
#              of          0.033333
# 06230550_IS  https       0.045864
#              t           0.045045
#              the         0.043407
#              co          0.041769
#              rt          0.036855
# 1515Ummah    rt          0.034058
#              the         0.029947
#              https       0.027598
#              in          0.026424
#              t           0.022314
# 1Dawlah_III  co          0.102621
#              https       0.102621
#              t           0.102621
#              of          0.061350
#              the         0.052984
# 432Mryam     t           0.051672
#              co          0.047112
#              https       0.045593
#              you         0.030395
#              khair       0.021277
# ALK___226    co          0.126280
#              https       0.126280
#              t           0.126280
#              amaqagency  0.020478
#              of          0.020478
# ...                           ...
# war_analysis rt          0.046056
#              t           0.026482
#              https       0.024755
#              the         0.023604
#              in          0.021877
# warreporter2 the         0.042662
#              rt          0.032708
#              https       0.027019
#              of          0.025028
#              t           0.023606
# warrnews     https       0.046196
#              t           0.043546
#              co          0.041052
#              in          0.033933
#              rt          0.024007
# wayf44rerr   https       0.033733
#              t           0.033733
#              co          0.028767
#              of          0.024315
#              in          0.022260
# wayff44rer   of          0.046512
#              the         0.046512
#              t           0.037209
#              co          0.032558
#              https       0.032558
# wayyf44rer   in          0.029126
#              t           0.029126
#              https       0.028155
#              co          0.027184
#              of          0.027184
#
# [560 rows x 1 columns]

# %%
c_d = tweets_words.username.nunique()
c_d
# Out:
# 112

# %%
idf = tweets_words.groupby('word')\
    .username\
    .nunique()\
    .to_frame()\
    .rename(columns={'username':'i_d'})\
    .sort_values('i_d')
idf.head()
# Out:
#             i_d
# word
# karm          1
# mzxjku3w09    1
# mzrjbcdhoq    1
# mznsrelwxq    1
# mzn9frklqe    1

# %%
idf['idf'] = np.log(c_d/idf.i_d.values)

idf.head()
# Out:
#             i_d       idf
# word
# karm          1  4.718499
# mzxjku3w09    1  4.718499
# mzrjbcdhoq    1  4.718499
# mznsrelwxq    1  4.718499
# mzn9frklqe    1  4.718499

# %%
tf_idf = tf.join(idf)

tf_idf.head()
# Out:
#                       n_w  n_d        tf  i_d       idf
# username  word
# 04_8_1437 https        48  870  0.055172  109  0.027151
#           t            47  870  0.054023  109  0.027151
#           co           46  870  0.052874  109  0.027151
#           amaqagency   43  870  0.049425   36  1.134980
#           of           29  870  0.033333  108  0.036368

# %%
tf_idf['tf_idf'] = tf_idf.tf * tf_idf.idf
tf_idf.head()
# Out:
#                       n_w  n_d        tf  i_d       idf    tf_idf
# username  word
# 04_8_1437 https        48  870  0.055172  109  0.027151  0.001498
#           t            47  870  0.054023  109  0.027151  0.001467
#           co           46  870  0.052874  109  0.027151  0.001436
#           amaqagency   43  870  0.049425   36  1.134980  0.056097
#           of           29  870  0.033333  108  0.036368  0.001212

# %%
pretty_plot_top_n(tf_idf['tf_idf'])
# Out:
#                                  tf_idf
# username     word
# 04_8_1437    amaqagency        0.056097
#              khilafahnews      0.019121
#              rigged            0.015320
#              1437              0.014852
#              app               0.012134
# 06230550_IS  loool             0.008187
#              5million          0.007729
#              afghanrace        0.007729
#              maslahat          0.007729
#              preaches          0.007729
# 1515Ummah    malle111elf       0.033092
#              wayf44rer         0.011349
#              lililllililli     0.011083
#              ankara            0.008264
#              barida            0.007091
# 1Dawlah_III  wilayataljazirah  0.012138
#              wilayatninawa     0.011213
#              qarytain          0.010526
#              wilayatalbarakah  0.010094
#              wilayatarraqqah   0.009843
# 432Mryam     upp0rt            0.085646
#              blvrnasiha        0.071710
#              jazakallah        0.038445
#              ukhti             0.034486
#              khair             0.032775
# ALK___226    4yuo33mcgl        0.032208
#              lgzvcabnfj        0.032208
#              puaucl1lcs        0.032208
#              360               0.027477
#              720               0.027477
# ...                                 ...
# war_analysis maghrebiwt        0.011612
#              shamibritaani     0.010866
#              adamhasakah112    0.008149
#              khorasan15        0.008149
#              nidalgazaui       0.007739
# warreporter2 didyouknowvs      0.073098
#              thevictoryseri4   0.034346
#              revelations       0.010304
#              victorynewshd     0.009266
#              did               0.008440
# warrnews     nidalgazaui       0.011684
#              gaza              0.008104
#              hamas             0.007660
#              warnews24         0.006066
#              alqassam          0.005020
# wayf44rerr   zuwaid            0.013694
#              mozlemgurl        0.013123
#              sinai             0.011800
#              egyptian          0.008752
#              zor               0.008606
# wayff44rer   rafahh            0.046496
#              searcherv         0.037445
#              explosion         0.030278
#              sukhna            0.027225
#              egyptian          0.027170
# wayyf44rer   gt                0.015369
#              kyrgyzstan        0.013743
#              uzbeki            0.013743
#              zuwaid            0.012941
#              qaryatayn         0.012811
#
# [560 rows x 1 columns]
