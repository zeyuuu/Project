# %% [markdown]
# # Exam Project: The formation of ISIS' Social Media Network

# %% [markdown]
# Group members: Zeyu Zhao, Helge Zille, Edith Zink, Sina Smid

# %%
import os
import requests
import re

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Data import:**
# - Dataset is downloaded from Kaggle (https://www.kaggle.com/fifthtribe/how-isis-uses-twitter)
# - Some of text is in Arabic, this will be ignored (encoding = 'Latin-1') and only Latin (English?) text will be used in the analysis

# %%
data = pd.read_csv('tweets_1.csv')
data.head()
data.dtypes
# Out:
# name              object
# username          object
# description       object
# location          object
# followers          int64
# numberstatuses     int64
# time              object
# tweets            object
# dtype: object

# %% [markdown]
# **Data cleaning:**
# - Prepare `tweets` column for text analysis

# %%
print(data.location.value_counts())  # Funny entries, I think :)
# Out:
# Read my blog                                     1475
# world                                            1191
# Worldwide contributions                           998
# Texas, USA                                        993
# اُمتِ مُسلمہ ولایت کشمیر                          709
# United States                                     587
# 28th Street, Qamar Precint                        426
# Germany                                           397
# Dunya                                             366
# Male'. Maldives.                                  333
# S.Wazirstan|Mahsud not a Wazir                    318
# Middle of Nowhere                                 303
# dar al-kufr                                       285
# Nowhere                                           234
# Wilayah Kashmir                                   231
# München, Deutschland                              193
# Bandar Seri Begawan, Negara Brunei Darussalam     182
# Geneva, Switzerland                               166
# Ghurabā                                           159
# Among The Muslims                                 152
# Gaziantep, Turkey                                 146
# Wilayat Hadramaut                                 134
# أسير الدنيا                                       100
# Singaparna, Indonesia                             100
# Antas, Bahia                                       99
# Land of Allah                                      97
# EU                                                 97
# Earth                                              96
# Punch, Jammu And Kashmir                           95
# Among mushrikeen                                   93
# Wilayah Twitter                                    89
# Al-Battar Media Foundatiom                         80
# Lake City, GA                                      68
# Guetto                                             58
# I hate snitches                                    49
# darl mushrequeen                                   47
# Amsterdam, The Netherlands                         45
# خارج الخلافة                                       42
# Don't need to know                                 40
# England, United Kingdom                            27
# AP                                                 25
# سرت‎ Sirte                                         23
# 40+Suspension for the truth!                       23
# noway                                              15
# Islamic State                                      14
# Dar Al Kufr                                        14
# yamin, yasār raqum ١٤                              10
# .                                                   4
# Prison ( Darul Kufr )                               4
# Name: location, dtype: int64

# %%
# time as datetime
data['time'] = pd.to_datetime(data.time)

# %% [markdown]
# **Language detection on tweets**
# Copied from [Kaggle](https://www.kaggle.com/mrisdal/most-commonly-used-natural-languages)
# - [the package](https://github.com/saffsd/langid.py)
# - [the codes](https://en.wikipedia.org/wiki/List_of_ISO_639-1_codes)

# %%
import langid   # identify languages based on tweets
predictions = [langid.classify(tweet) for tweet in data['tweets']]

# %%
data['language'], data['lang_val'] =  zip(*predictions)

# Dummy for ENGLISH TRANSLATION
print(data['tweets'][0])  # example of translated tweet

data['translated'] = [tweet.startswith('ENGLISH') for tweet in data['tweets']]
print(data.translated.value_counts())  # only 10 tweets translated from the beginning


# Which are the most common languages:
print("The ten most used languages are: \n", data['language'].value_counts().head(10))

# Graph for overview
colors=sns.cubehelix_palette(8) 
pd.Series(data['language']).value_counts().head(10).plot(kind = "bar",
                                                        figsize=(6,3),
                                                        color=colors,
                                                        fontsize=14,
                                                        rot=45,
                                                        title = "Top 10 most common languages")
# Out:
# ENGLISH TRANSLATION: 'A MESSAGE TO THE TRUTHFUL IN SYRIA - SHEIKH ABU MUHAMMED AL MAQDISI: http://t.co/73xFszsjvr http://t.co/x8BZcscXzq
# False    17399
# True        11
# Name: translated, dtype: int64
# The ten most used languages are:
#  en    14556
# ar      742
# fr      610
# ms      198
# id      182
# la       85
# sw       78
# de       75
# es       64
# nl       57
# Name: language, dtype: int64

# %% [markdown]
# **Tokenization**

# %%
# Extract the @ tags and remove it from the tweets
def extract_from_to_column(df, regex, from_col, to_col):
    df[to_col]=df[from_col].apply(lambda x: " ".join(regex.findall(x)))
    return df

def remove_from_body(df,regex):
    df['tweets']=df.tweets.apply(lambda x: re.sub(regex,'',x))
    return df

regex1 = re.compile("@(\S+)")   #tagged users
regex2 = re.compile("http\S+")  # urls
regex3 = re.compile("ENGLISH TRANS[^:]*:") #prefix
regex4 = re.compile("#(\S+)") #hashtags

data = extract_from_to_column(data, regex1, 'tweets', 'tags')
data = remove_from_body(data, regex1)

data = extract_from_to_column(data, regex2, 'tweets', 'links')
data = remove_from_body(data, regex2)

data = remove_from_body(data, regex3)

data.tags = data.tags.str.split()

# %%
# Tokenize sentences into words: split into words
data['tweets_rec'] = data.tweets.str.strip().str.split('[\W_]+')
data
# Out:
#                      name         username  \
# 0           GunsandCoffee  GunsandCoffee70
# 1           GunsandCoffee  GunsandCoffee70
# 2           GunsandCoffee  GunsandCoffee70
# 3           GunsandCoffee  GunsandCoffee70
# 4           GunsandCoffee  GunsandCoffee70
# 5           GunsandCoffee  GunsandCoffee70
# 6           GunsandCoffee  GunsandCoffee70
# 7           GunsandCoffee  GunsandCoffee70
# 8           GunsandCoffee  GunsandCoffee70
# 9           GunsandCoffee  GunsandCoffee70
# 10          GunsandCoffee  GunsandCoffee70
# 11          GunsandCoffee  GunsandCoffee70
# 12          GunsandCoffee  GunsandCoffee70
# 13          GunsandCoffee  GunsandCoffee70
# 14          GunsandCoffee  GunsandCoffee70
# 15          GunsandCoffee  GunsandCoffee70
# 16          GunsandCoffee  GunsandCoffee70
# 17          GunsandCoffee  GunsandCoffee70
# 18          GunsandCoffee  GunsandCoffee70
# 19          GunsandCoffee  GunsandCoffee70
# 20          GunsandCoffee  GunsandCoffee70
# 21          GunsandCoffee  GunsandCoffee70
# 22          GunsandCoffee  GunsandCoffee70
# 23          GunsandCoffee  GunsandCoffee70
# 24          GunsandCoffee  GunsandCoffee70
# 25          GunsandCoffee  GunsandCoffee70
# 26          GunsandCoffee  GunsandCoffee70
# 27          GunsandCoffee  GunsandCoffee70
# 28          GunsandCoffee  GunsandCoffee70
# 29     Abu Layth Al Hindi  AbuLaythAlHindi
# ...                   ...              ...
# 17380                  ☝️       melvynlion
# 17381           N i d a l      Nidalgazaui
# 17382         Anaksabil97          nvor85j
# 17383           N i d a l      Nidalgazaui
# 17384        Mountain Man   Mountainjjoool
# 17385         Anaksabil97          nvor85j
# 17386           N i d a l      Nidalgazaui
# 17387        كتكات كوكونت    Uncle_SamCoco
# 17388         Anaksabil97          nvor85j
# 17389        كتكات كوكونت    Uncle_SamCoco
# 17390         Anaksabil97          nvor85j
# 17391        كتكات كوكونت    Uncle_SamCoco
# 17392        كتكات كوكونت    Uncle_SamCoco
# 17393    one who believes           ro34th
# 17394      Musa Al-Ansari        lNSlDEWAR
# 17395        كتكات كوكونت    Uncle_SamCoco
# 17396        كتكات كوكونت    Uncle_SamCoco
# 17397        كتكات كوكونت    Uncle_SamCoco
# 17398        كتكات كوكونت    Uncle_SamCoco
# 17399        كتكات كوكونت    Uncle_SamCoco
# 17400        Mountain Man   Mountainjjoool
# 17401        Mountain Man   Mountainjjoool
# 17402        كتكات كوكونت    Uncle_SamCoco
# 17403         Anaksabil97          nvor85j
# 17404        كتكات كوكونت    Uncle_SamCoco
# 17405         Anaksabil97          nvor85j
# 17406         Anaksabil97          nvor85j
# 17407         Anaksabil97          nvor85j
# 17408         Anaksabil97          nvor85j
# 17409    one who believes           ro34th
#
#                                              description           location  \
# 0           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 1           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 2           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 3           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 4           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 5           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 6           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 7           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 8           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 9           ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 10          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 11          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 12          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 13          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 14          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 15          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 16          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 17          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 18          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 19          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 20          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 21          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 22          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 23          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 24          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 25          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 26          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 27          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 28          ENGLISH TRANSLATIONS: http://t.co/QLdJ0ftews                NaN
# 29     Kik: abulayth2014. Ex South African. Currently...      Islamic State
# ...                                                  ...                ...
# 17380  If you have trust in Allah, you have no need t...                NaN
# 17381  17yr. old Freedom Activist\n/Correspondence of...            Germany
# 17382                                                NaN                NaN
# 17383  17yr. old Freedom Activist\n/Correspondence of...            Germany
# 17384                                                NaN                NaN
# 17385                                                NaN                NaN
# 17386  17yr. old Freedom Activist\n/Correspondence of...            Germany
# 17387  Here to defend the  American freedom and also ...         Texas, USA
# 17388                                                NaN                NaN
# 17389  Here to defend the  American freedom and also ...         Texas, USA
# 17390                                                NaN                NaN
# 17391  Here to defend the  American freedom and also ...         Texas, USA
# 17392  Here to defend the  American freedom and also ...         Texas, USA
# 17393  Torah Observant, follower of the Prophet Yeshu...        dar al-kufr
# 17394      War Investigator. Civil Engineer. MENA Region  Gaziantep, Turkey
# 17395  Here to defend the  American freedom and also ...         Texas, USA
# 17396  Here to defend the  American freedom and also ...         Texas, USA
# 17397  Here to defend the  American freedom and also ...         Texas, USA
# 17398  Here to defend the  American freedom and also ...         Texas, USA
# 17399  Here to defend the  American freedom and also ...         Texas, USA
# 17400                                                NaN                NaN
# 17401                                                NaN                NaN
# 17402  Here to defend the  American freedom and also ...         Texas, USA
# 17403                                                NaN                NaN
# 17404  Here to defend the  American freedom and also ...         Texas, USA
# 17405                                                NaN                NaN
# 17406                                                NaN                NaN
# 17407                                                NaN                NaN
# 17408                                                NaN                NaN
# 17409  Torah Observant, follower of the Prophet Yeshu...        dar al-kufr
#
#        followers  numberstatuses                time  \
# 0            640              49 2015-01-06 21:07:00
# 1            640              49 2015-01-06 21:27:00
# 2            640              49 2015-01-06 21:29:00
# 3            640              49 2015-01-06 21:37:00
# 4            640              49 2015-01-06 21:45:00
# 5            640              49 2015-01-06 21:51:00
# 6            640              49 2015-01-06 22:04:00
# 7            640              49 2015-01-06 22:06:00
# 8            640              49 2015-01-06 22:17:00
# 9            640              49 2015-01-10 00:05:00
# 10           640              49 2015-01-10 00:08:00
# 11           640              49 2015-01-12 23:10:00
# 12           640              49 2015-01-22 20:14:00
# 13           640              49 2015-01-22 20:47:00
# 14           640              49 2015-02-09 10:54:00
# 15           640              49 2015-02-12 13:03:00
# 16           640              49 2015-02-12 13:11:00
# 17           640              49 2015-02-16 15:57:00
# 18           640              49 2015-02-20 16:28:00
# 19           640              49 2015-02-20 16:29:00
# 20           640              49 2015-02-20 16:30:00
# 21           640              49 2015-02-26 20:36:00
# 22           640              49 2015-02-26 20:40:00
# 23           640              49 2015-02-28 23:35:00
# 24           640              49 2015-03-04 07:31:00
# 25           640              49 2015-04-01 13:18:00
# 26           640              49 2015-05-13 21:16:00
# 27           640              49 2015-05-29 09:53:00
# 28           640              49 2015-06-03 11:16:00
# 29            68              18 2015-07-07 06:02:00
# ...          ...             ...                 ...
# 17380         81             478 2016-05-13 14:50:00
# 17381       4662            5966 2016-05-13 14:54:00
# 17382        238             133 2016-05-13 15:10:00
# 17383       4662            5966 2016-05-13 15:11:00
# 17384        427             142 2016-05-13 15:12:00
# 17385        238             133 2016-05-13 15:13:00
# 17386       4662            5966 2016-05-13 15:15:00
# 17387       1798            7028 2016-05-13 15:17:00
# 17388        238             133 2016-05-13 15:17:00
# 17389       1798            7028 2016-05-13 15:19:00
# 17390        238             133 2016-05-13 15:21:00
# 17391       1798            7028 2016-05-13 15:21:00
# 17392       1798            7028 2016-05-13 15:23:00
# 17393       1482           33091 2016-05-13 15:26:00
# 17394        528             259 2016-05-13 15:27:00
# 17395       1798            7028 2016-05-13 15:27:00
# 17396       1798            7028 2016-05-13 15:30:00
# 17397       1798            7028 2016-05-13 15:32:00
# 17398       1798            7028 2016-05-13 15:35:00
# 17399       1798            7028 2016-05-13 15:37:00
# 17400        427             142 2016-05-13 15:40:00
# 17401        427             142 2016-05-13 15:42:00
# 17402       1798            7028 2016-05-13 15:43:00
# 17403        238             133 2016-05-13 15:44:00
# 17404       1798            7028 2016-05-13 15:45:00
# 17405        238             133 2016-05-13 15:46:00
# 17406        238             133 2016-05-13 15:50:00
# 17407        238             133 2016-05-13 15:51:00
# 17408        238             133 2016-05-13 16:07:00
# 17409       1482           33091 2016-05-13 16:10:00
#
#                                                   tweets language    lang_val  \
# 0      : 'A MESSAGE TO THE TRUTHFUL IN SYRIA - SHEIKH...       nl  -25.419356
# 1      : SHEIKH FATIH AL JAWLANI 'FOR THE PEOPLE OF I...       pl  -15.531152
# 2      : FIRST AUDIO MEETING WITH SHEIKH FATIH AL JAW...       de  -32.171995
# 3      : SHEIKH NASIR AL WUHAYSHI (HA), LEADER OF AQA...       en  -11.085660
# 4      : AQAP: 'RESPONSE TO SHEIKH BAGHDADIS STATEMEN...       en    9.061840
# 5      THE SECOND CLIP IN A DA'WAH SERIES BY A SOLDIE...       pl  -21.223762
# 6                                      : OH MURABIT! :         en   -1.319836
# 7      : 'A COLLECTION OF THE WORDS OF THE U'LAMA REG...       en   -0.862855
# 8      Aslm Please share our new account after the pr...       en -250.258157
# 9      : AQAP STATEMENT REGARDING THE BLESSED RAID IN...       en    9.061840
# 10                                                             rw  -86.089931
# 11     NEW LINK, AFTER PREVIOUS ONE TAKEN DOWN:AQAP-'...       pl  -19.038125
# 12                                                   :         en  -35.868412
# 13     SHEIKH ABU HASSAN AL KUWAITI (HA): ADVICE OF N...       pl  -19.410138
# 14                            Not translating it either.       en  -91.834425
# 15     Aslm, anybody translating the new JN video? Wi...       en -181.734841
# 16         So we will translate it then inshallah let...       en -283.129786
# 17           half way through, a few more days inshal...       en -265.095132
# 18          Aslm, we have completed the translation w...       en -262.934536
# 19         reports and words of the Syrian people, wi...       en -305.663265
# 20          inshallah. Should we still finish it, or ...       en -161.334939
# 21     NEW links for #JN Video - ENG Subs: The Path o...       en  -74.929858
# 22     DOWNLOAD #JN Video With English Subtitles: The...       ar -155.266175
# 23     Video by  with Eng Subtitles: 'Save Aleppo' \n...       en  -76.112294
# 24     : A Pamphlet Released By #JN Regarding #IS \nG...       en -124.574979
# 25     Aslm, anybody translating the new audio of She...       en -277.048269
# 26                            Aslm, Will do it inshallah       en -185.617644
# 27     RT  Rules Of Imarah Part2 - Conditions of Imam...       en  -86.540960
# 28            : Dialogue with Sheikh Tartoosi Part 2 \n        en  -56.988494
# 29     ‍‌‌‌‌‍‌‌‌🔻‌‌[ الإثنين  1436/9/19 هـ ]‍‌‌‌‌‍‍‍‍...       fa -836.730250
# ...                                                  ...      ...         ...
# 17380          RT  #IbnAlQayyim #Allah Ta`Aala\n#AlQalb        id  -45.229056
# 17381  Local Source: Daily and Heavy Clashes between ...       en -161.977033
# 17382  #Breaking\n#IslamicState \n\n#Fallujah \n#Euro...       id  -13.481333
# 17383  HUGE\n\nAt least 300 Irani IRCG Soldiers were ...       en -209.958997
# 17384  RT  "A single expedition in the afternoon or f...       en -375.213868
# 17385  #Breaking\n#IslamicState Forces assault Iraqi ...       en -125.895511
# 17386  RT  These images of the massacre perpetrated b...       en -372.766234
# 17387                        j'aimerai bien savoir aussi       fr -125.279572
# 17388  3 Martyrdom bombers detonate their Xplosive be...       en -220.092435
# 17389   une légende de twitter, il a rejoint le Panth...       fr -301.183993
# 17390  #Breaking \n#IslamicState \n  || 3 Martydom bo...       en -102.757161
# 17391   pas mal ce tweet toi aussi tu vas percer comm...       fr -382.845775
# 17392  RT  Mais qui a envie d'entendre quelqu'un fair...       fr -606.290734
# 17393  #AmaqAgency so far 9 Iraqi hummers, an autocan...       en -282.253144
# 17394  RT  #Exclusive Photo: #Hezbollah Mustafa Badre...       en -147.425996
# 17395  According to the SOHR, JAN is responsible of t...       en -306.346172
# 17396  Notice that the fighter who trample the bodies...       en -329.948526
# 17397  The local commander of Ahrar Al Sham appears i...       en -281.675383
# 17398  RT  #Syria: Who was Mustapha #Badreddine, the ...       en -129.191392
# 17399  RT  Erratum shiaa Afghan fighters who die in S...       en -426.841510
# 17400  RT  Aamaq footage:\nDestruction of Iraqi force...       en -190.620962
# 17401  Heavy battles going on in Al Karmah northeast ...       en -141.925551
# 17402  "Is the Islamic State trying  to draw Turkey i...       en  -85.744255
# 17403  9 Hummers an autocannon and a field artillery ...       en -249.897658
# 17404  #LT Notice that this possible strategy was men...       en -219.200245
# 17405  #Breaking\n#IslamicState \n#AmaqAgency \n\n#Fr...       en  -35.638466
# 17406  #Breaking\n\n Iraqi forces bulldozer destroyed...       en -214.685773
# 17407  #Breaking \n#AmaqAgency \n#IslamicState \n\n#E...       en  -31.365999
# 17408  #PhotoReport \n#WilayatDimasiqh \n\n📷The Condu...       en -104.747762
# 17409  #AmaqAgency Destroyed and burning Iraqi Forces...       en  -66.385111
#
#        translated tags links  \
# 0            True   []
# 1            True   []
# 2            True   []
# 3            True   []
# 4            True   []
# 5           False   []
# 6            True   []
# 7            True   []
# 8           False   []
# 9            True   []
# 10          False   []
# 11          False   []
# 12           True   []
# 13          False   []
# 14          False   []
# 15          False   []
# 16          False   []
# 17          False   []
# 18          False   []
# 19          False   []
# 20          False   []
# 21          False   []
# 22          False   []
# 23          False   []
# 24           True   []
# 25          False   []
# 26          False   []
# 27          False   []
# 28           True   []
# 29          False   []
# ...           ...  ...   ...
# 17380       False   []
# 17381       False   []
# 17382       False   []
# 17383       False   []
# 17384       False   []
# 17385       False   []
# 17386       False   []
# 17387       False   []
# 17388       False   []
# 17389       False   []
# 17390       False   []
# 17391       False   []
# 17392       False   []
# 17393       False   []
# 17394       False   []
# 17395       False   []
# 17396       False   []
# 17397       False   []
# 17398       False   []
# 17399       False   []
# 17400       False   []
# 17401       False   []
# 17402       False   []
# 17403       False   []
# 17404       False   []
# 17405       False   []
# 17406       False   []
# 17407       False   []
# 17408       False   []
# 17409       False   []
#
#                                               tweets_rec
# 0      [, A, MESSAGE, TO, THE, TRUTHFUL, IN, SYRIA, S...
# 1      [, SHEIKH, FATIH, AL, JAWLANI, FOR, THE, PEOPL...
# 2      [, FIRST, AUDIO, MEETING, WITH, SHEIKH, FATIH,...
# 3      [, SHEIKH, NASIR, AL, WUHAYSHI, HA, LEADER, OF...
# 4      [, AQAP, RESPONSE, TO, SHEIKH, BAGHDADIS, STAT...
# 5      [THE, SECOND, CLIP, IN, A, DA, WAH, SERIES, BY...
# 6                                      [, OH, MURABIT, ]
# 7      [, A, COLLECTION, OF, THE, WORDS, OF, THE, U, ...
# 8      [Aslm, Please, share, our, new, account, after...
# 9      [, AQAP, STATEMENT, REGARDING, THE, BLESSED, R...
# 10                                                    []
# 11     [NEW, LINK, AFTER, PREVIOUS, ONE, TAKEN, DOWN,...
# 12                                                  [, ]
# 13     [SHEIKH, ABU, HASSAN, AL, KUWAITI, HA, ADVICE,...
# 14                      [Not, translating, it, either, ]
# 15     [Aslm, anybody, translating, the, new, JN, vid...
# 16     [So, we, will, translate, it, then, inshallah,...
# 17     [half, way, through, a, few, more, days, insha...
# 18     [Aslm, we, have, completed, the, translation, ...
# 19     [reports, and, words, of, the, Syrian, people,...
# 20     [inshallah, Should, we, still, finish, it, or,...
# 21     [NEW, links, for, JN, Video, ENG, Subs, The, P...
# 22     [DOWNLOAD, JN, Video, With, English, Subtitles...
# 23     [Video, by, with, Eng, Subtitles, Save, Aleppo...
# 24     [, A, Pamphlet, Released, By, JN, Regarding, I...
# 25     [Aslm, anybody, translating, the, new, audio, ...
# 26                       [Aslm, Will, do, it, inshallah]
# 27     [RT, Rules, Of, Imarah, Part2, Conditions, of,...
# 28         [, Dialogue, with, Sheikh, Tartoosi, Part, 2]
# 29     [, الإثنين, 1436, 9, 19, هـ, الن, شرة, صوتي, ة...
# ...                                                  ...
# 17380         [RT, IbnAlQayyim, Allah, Ta, Aala, AlQalb]
# 17381  [Local, Source, Daily, and, Heavy, Clashes, be...
# 17382   [, Breaking, IslamicState, Fallujah, Eurovision]
# 17383  [HUGE, At, least, 300, Irani, IRCG, Soldiers, ...
# 17384  [RT, A, single, expedition, in, the, afternoon...
# 17385  [, Breaking, IslamicState, Forces, assault, Ir...
# 17386  [RT, These, images, of, the, massacre, perpetr...
# 17387                  [j, aimerai, bien, savoir, aussi]
# 17388  [3, Martyrdom, bombers, detonate, their, Xplos...
# 17389  [une, légende, de, twitter, il, a, rejoint, le...
# 17390  [, Breaking, IslamicState, 3, Martydom, bomber...
# 17391  [pas, mal, ce, tweet, toi, aussi, tu, vas, per...
# 17392  [RT, Mais, qui, a, envie, d, entendre, quelqu,...
# 17393  [, AmaqAgency, so, far, 9, Iraqi, hummers, an,...
# 17394  [RT, Exclusive, Photo, Hezbollah, Mustafa, Bad...
# 17395  [According, to, the, SOHR, JAN, is, responsibl...
# 17396  [Notice, that, the, fighter, who, trample, the...
# 17397  [The, local, commander, of, Ahrar, Al, Sham, a...
# 17398  [RT, Syria, Who, was, Mustapha, Badreddine, th...
# 17399  [RT, Erratum, shiaa, Afghan, fighters, who, di...
# 17400  [RT, Aamaq, footage, Destruction, of, Iraqi, f...
# 17401  [Heavy, battles, going, on, in, Al, Karmah, no...
# 17402  [, Is, the, Islamic, State, trying, to, draw, ...
# 17403  [9, Hummers, an, autocannon, and, a, field, ar...
# 17404  [, LT, Notice, that, this, possible, strategy,...
# 17405  [, Breaking, IslamicState, AmaqAgency, Fridayt...
# 17406  [, Breaking, Iraqi, forces, bulldozer, destroy...
# 17407  [, Breaking, AmaqAgency, IslamicState, EastofH...
# 17408  [, PhotoReport, WilayatDimasiqh, The, Conduct,...
# 17409  [, AmaqAgency, Destroyed, and, burning, Iraqi,...
#
# [17410 rows x 14 columns]

# %%
# Break words into different rows, by username
rows = list()
for row in data[['username', 'tweets_rec']].iterrows():
    r = row[1]
    for word in r.tweets_rec:
        rows.append((r.username, word))

tweets_words = pd.DataFrame(rows, columns=['username', 'word'])
tweets_words.head(20)
# Out:
#            username      word
# 0   GunsandCoffee70
# 1   GunsandCoffee70         A
# 2   GunsandCoffee70   MESSAGE
# 3   GunsandCoffee70        TO
# 4   GunsandCoffee70       THE
# 5   GunsandCoffee70  TRUTHFUL
# 6   GunsandCoffee70        IN
# 7   GunsandCoffee70     SYRIA
# 8   GunsandCoffee70    SHEIKH
# 9   GunsandCoffee70       ABU
# 10  GunsandCoffee70  MUHAMMED
# 11  GunsandCoffee70        AL
# 12  GunsandCoffee70   MAQDISI
# 13  GunsandCoffee70
# 14  GunsandCoffee70
# 15  GunsandCoffee70    SHEIKH
# 16  GunsandCoffee70     FATIH
# 17  GunsandCoffee70        AL
# 18  GunsandCoffee70   JAWLANI
# 19  GunsandCoffee70       FOR

# %%
# Removing empty cells
tweets_words = tweets_words[tweets_words.word.str.len() > 0]
tweets_words.head()
# Out:
#           username      word
# 1  GunsandCoffee70         A
# 2  GunsandCoffee70   MESSAGE
# 3  GunsandCoffee70        TO
# 4  GunsandCoffee70       THE
# 5  GunsandCoffee70  TRUTHFUL

# %%
# lower case words
tweets_words['word'] = tweets_words.word.str.lower()
tweets_words.head(100)
# Note: we still need to remove https and @, https is included as: 1st word) https, 2nd word) t, 3rd word) co (see below as example for row 20-22)
# Out:
#             username        word
# 1    GunsandCoffee70           a
# 2    GunsandCoffee70     message
# 3    GunsandCoffee70          to
# 4    GunsandCoffee70         the
# 5    GunsandCoffee70    truthful
# 6    GunsandCoffee70          in
# 7    GunsandCoffee70       syria
# 8    GunsandCoffee70      sheikh
# 9    GunsandCoffee70         abu
# 10   GunsandCoffee70    muhammed
# 11   GunsandCoffee70          al
# 12   GunsandCoffee70     maqdisi
# 15   GunsandCoffee70      sheikh
# 16   GunsandCoffee70       fatih
# 17   GunsandCoffee70          al
# 18   GunsandCoffee70     jawlani
# 19   GunsandCoffee70         for
# 20   GunsandCoffee70         the
# 21   GunsandCoffee70      people
# 22   GunsandCoffee70          of
# 23   GunsandCoffee70   integrity
# 24   GunsandCoffee70   sacrifice
# 25   GunsandCoffee70          is
# 26   GunsandCoffee70        easy
# 29   GunsandCoffee70       first
# 30   GunsandCoffee70       audio
# 31   GunsandCoffee70     meeting
# 32   GunsandCoffee70        with
# 33   GunsandCoffee70      sheikh
# 34   GunsandCoffee70       fatih
# ..               ...         ...
# 80   GunsandCoffee70        link
# 83   GunsandCoffee70          oh
# 84   GunsandCoffee70     murabit
# 87   GunsandCoffee70           a
# 88   GunsandCoffee70  collection
# 89   GunsandCoffee70          of
# 90   GunsandCoffee70         the
# 91   GunsandCoffee70       words
# 92   GunsandCoffee70          of
# 93   GunsandCoffee70         the
# 94   GunsandCoffee70           u
# 95   GunsandCoffee70        lama
# 96   GunsandCoffee70   regarding
# 97   GunsandCoffee70      dawlah
# 99   GunsandCoffee70        aslm
# 100  GunsandCoffee70      please
# 101  GunsandCoffee70       share
# 102  GunsandCoffee70         our
# 103  GunsandCoffee70         new
# 104  GunsandCoffee70     account
# 105  GunsandCoffee70       after
# 106  GunsandCoffee70         the
# 107  GunsandCoffee70    previous
# 108  GunsandCoffee70         one
# 109  GunsandCoffee70         was
# 110  GunsandCoffee70   suspended
# 113  GunsandCoffee70        aqap
# 114  GunsandCoffee70   statement
# 115  GunsandCoffee70   regarding
# 116  GunsandCoffee70         the
#
# [100 rows x 2 columns]

# %%
# dropping https and t, co
tweets_words.drop(['https', 't', 'co']) 
tweets_words.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-cb7d8478ad01> in <module>
#       1 # dropping https and t, co
# ----> 2 tweets_words.drop(['https', 't', 'co'])
#       3 tweets_words.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['https' 't' 'co'] not found in axis"

# %% [markdown]
# **Note:** In the next part, I played around with the data to see what is possible using a blogpost online: https://sigdelta.com/blog/text-analysis-in-pandas/, which uses a TF-IDF method

# %%
counts = tweets_words.groupby('username')\
    .word.value_counts()\
    .to_frame()\
    .rename(columns={'word':'n_w'})
counts.head()

# %%
def pretty_plot_top_n(series, top_n=5, index_level=0):
    r = series\
    .groupby(level=index_level)\
    .nlargest(top_n)\
    .reset_index(level=index_level, drop=True)
    r.plot.bar()
    return r.to_frame()

pretty_plot_top_n(counts['n_w'])

# %%
word_sum = counts.groupby(level=0)\
    .sum()\
    .rename(columns={'n_w': 'n_d'})
word_sum

# %%
tf = counts.join(word_sum)

tf['tf'] = tf.n_w/tf.n_d

tf.head()

# %%
pretty_plot_top_n(tf['tf'])

# %%
c_d = tweets_words.username.nunique()
c_d

# %%
idf = tweets_words.groupby('word')\
    .username\
    .nunique()\
    .to_frame()\
    .rename(columns={'username':'i_d'})\
    .sort_values('i_d')
idf.head()

# %%
idf['idf'] = np.log(c_d/idf.i_d.values)

idf.head()

# %%
tf_idf = tf.join(idf)

tf_idf.head()

# %%
tf_idf['tf_idf'] = tf_idf.tf * tf_idf.idf
tf_idf.head()

# %%
pretty_plot_top_n(tf_idf['tf_idf'])
