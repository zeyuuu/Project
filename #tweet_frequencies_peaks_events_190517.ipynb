# %% [markdown]
# # Descriptive Analysis

# %%
import os
import requests
import re

import networkx as nx

import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot') # makes the bar charts red on grey background with grid, I think it is nice

from collections import Counter

from our_functions import *

import datetime

# %%
# This is to use the same red in all our graphs (with only one color), can obviously adjusted if you prefer other colors!
print( plt.rcParams['axes.prop_cycle'].by_key()['color'])
default_red = plt.rcParams['axes.prop_cycle'].by_key()['color'][0]
# Out:
# ['#E24A33', '#348ABD', '#988ED5', '#777777', '#FBC15E', '#8EBA42', '#FFB5B8']

# %%
df = read_tweets('tweets_1.csv')

re_tweets, actual_tweets = actual_retweets(df)

in_set, not_in_set = mentions(actual_tweets)

# %%
# Visualization using actual events:
time_tweets = df.date.value_counts().sort_index()
april_tweets = time_tweets.loc['2015-09-1':'2015-12-31']

fig = plt.figure(figsize=(16,7))
ax = fig.add_subplot(111)
line = ax.plot(april_tweets)

sep05 = 'Airstrikes against ISIS'
ax.annotate(sep05, xytext=('2015-9-5', 200), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-9-5', 60))

sep24 = 'Suicide bombing at mosque in Sanaa'
ax.annotate(sep24, xytext=('2015-9-24', 230), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-9-24',55))

dec11 = 'Tell Tamer bombing'
ax.annotate(dec11, xytext=('2015-12-11', 190), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-12-11', 40))


ax.set_ylim(0,270)
plt.title('Tweets per Day and Peak Events in September to December 2015')
plt.show()

# %%
# Visualization using actual events:
time_tweets = df.date.value_counts().sort_index()
april_tweets = time_tweets.loc['2015-09-1':'2015-12-31']

fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot(111)
line = ax.plot(april_tweets)

oct10 = 'Ankara bombings'
ax.annotate(oct10, xytext=('2015-10-10', 150), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-10-10', 15))

oct31 = 'Metrojet Flight 9268'
ax.annotate(oct31, xytext=('2015-10-31', 150), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-10-31',10))

nov12 = 'Beirut bombings'
ax.annotate(nov12, xytext=('2015-11-12', 150), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-11-12', 20))

nov13 = 'Paris attacks'
ax.annotate(nov13, xytext=('2015-11-13', 130), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-11-13', 15))

nov24 = 'Tunis bombings'
ax.annotate(nov12, xytext=('2015-11-24', 150), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-11-24', 5))

dec02 = 'San Bernadino attack'
ax.annotate(dec02, xytext=('2015-12-2', 150), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-12-2', 7))

dec11 = 'Tell Tamer bombings'
ax.annotate(dec11, xytext=('2015-12-11', 150), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-12-11', 10))

dec30 = 'al-Qamishli bombings'
ax.annotate(dec30, xytext=('2015-12-30', 150), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2015-12-30', 30))


ax.set_ylim(0,200)
plt.title('Tweets per Day and major ISIS terror attacks in September to December 2015')
plt.show()

# %%
# Visualization using actual events:
time_tweets = df.date.value_counts().sort_index()
april_tweets = time_tweets.loc['2016-1-1':'2016-3-1']

fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)
line = ax.plot(april_tweets)

jan16 = 'Deir ez-Zor massarce'
ax.annotate(jan16, xytext=('2016-1-16', 400), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-16', 100))

#jan29 = 'Attack on mosque in Saudi Arabia'
#ax.annotate(jan29, xytext=('2016-1-29', 350), rotation=45,
#            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-29',55))

jan31 = 'Suicide bombing near mosque in Damascus'
ax.annotate(jan31, xytext=('2016-1-31', 570), rotation=0,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-31', 520))

feb04 = 'Saudi Arabia and UAE declare willingness to deploy ground troops'
ax.annotate(feb04, xytext=('2016-2-4', 580), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-2-4', 220))

feb19 = 'US airraid on ISIS camp'
ax.annotate(feb19, xytext=('2016-2-19', 500), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-2-19', 290))

feb25 = 'ISIS gets dislodged from Khanasir'
ax.annotate(feb25, xytext=('2016-2-25', 500), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-2-25', 210))


ax.set_ylim(0,600)
plt.title('Tweets per Day and Peak Events in January and February 2016')
plt.show()

# %%
# Visualization using actual events:
time_tweets = df.date.value_counts().sort_index()
april_tweets = time_tweets.loc['2016-1-1':'2016-3-1']

fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)
line = ax.plot(april_tweets)

jan07 = 'Zliten truck bombing'
ax.annotate(jan07, xytext=('2016-1-7', 400), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-7', 30))

jan12 = 'Istanbul bombing'
ax.annotate(jan12, xytext=('2016-1-12', 350), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-12',45))

jan14 = 'Jakarta attacks'
ax.annotate(jan14, xytext=('2016-1-14', 330), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-14', 40))

jan29 = 'Mahasen mosque attacks'
ax.annotate(jan29, xytext=('2016-1-29', 500), rotation=90,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-29', 160))

jan31 = 'Sayyidah Zaynab bombings'
ax.annotate(jan31, xytext=('2016-1-31', 570), rotation=0,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-31', 520))            
            
feb21 = 'Sayyidah Zaynab bombings'
ax.annotate(feb21, xytext=('2016-2-21', 300), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-2-21', 90))

feb21 = 'Homs bombings'
ax.annotate(feb21, xytext=('2016-2-21', 330), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-2-21', 190))


ax.set_ylim(0,600)
plt.title('Tweets per Day and major ISIS terror attacks in January and February 2016')
plt.show()

# %%
# Visualization using actual events:
time_tweets = df.date.value_counts().sort_index()
april_tweets = time_tweets.loc['2016-3-1':'2016-5-17']

fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)
line = ax.plot(april_tweets)

#jan16 = 'Executions in Dei al-Zor'
#ax.annotate(jan16, xytext=('2016-1-16', 400), rotation=45,
#            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-16', 100))

#jan29 = 'Attack on mosque in Saudi Arabia'
#ax.annotate(jan29, xytext=('2016-1-29', 350), rotation=45,
#            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-29',55))

#jan31 = 'Suicide bombing near mosque in Damascus'
#ax.annotate(jan31, xytext=('2016-1-31', 570), rotation=0,
#            arrowprops=dict(connectionstyle="arc3"), xy=('2016-1-31', 520))

#feb19 = 'US airraid on ISIS camp'
#ax.annotate(feb19, xytext=('2016-2-19', 500), rotation=45,
#            arrowprops=dict(connectionstyle="arc3"), xy=('2016-2-19', 270))

#feb25 = 'ISIS gets dislodged from Khanasir'
#ax.annotate(feb25, xytext=('2016-2-25', 500), rotation=45,
#            arrowprops=dict(connectionstyle="arc3"), xy=('2016-2-25', 270))

mar02 = 'ISIS kills SRF leader'
ax.annotate(mar02, xytext=('2016-3-2', 550), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-3-2', 230))

mar18 = 'Salah Abdeslam arrested in Brussels'
ax.annotate(mar18, xytext=('2016-3-18', 620), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-3-18',260))

mar22 = 'Brussels terror attacks'
ax.annotate(mar22, xytext=('2016-3-22', 400), rotation=85,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-3-22', 185))

mar25 = 'US forces kill ISIS finance minister'
ax.annotate(mar25, xytext=('2016-3-25', 650), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-3-25', 420))

mar24 = 'Syrian government retakes Palmyra'
ax.annotate(mar24, xytext=('2016-3-24', 680), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-3-24', 400))

apr01 = 'ISIS offensive in Mregel'
ax.annotate(apr01, xytext=('2016-4-1', 530), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-4-1', 220))

apr08 = 'Abu Sayyaf attacks on the Philippines'
ax.annotate(apr08, xytext=('2016-4-8', 650), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-4-8', 390))

apr14 = 'ISIS captures Hiwar Kallis'
ax.annotate(apr13, xytext=('2016-4-14', 530), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-4-14', 260))

apr25 = 'LGBT activists killed in Bangladesh'
ax.annotate(apr25, xytext=('2016-4-25', 600), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-4-25', 210))

may06 = 'US forces kill military emir for Anbar'
ax.annotate(may06, xytext=('2016-5-6', 670), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-5-6', 400))

may12 = 'Bagdad bombings'
ax.annotate(may12, xytext=('2016-5-12', 610), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-5-12', 450))

ax.set_ylim(0,700)
plt.title('Tweets per Day and Peak Events in March to May 2016')
plt.show()

# %%
# Visualization using actual events:
time_tweets = df.date.value_counts().sort_index()
april_tweets = time_tweets.loc['2016-3-1':'2016-5-17']

fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)
line = ax.plot(april_tweets)


mar19 = 'Istanbul bombing'
ax.annotate(mar19, xytext=('2016-3-19', 620), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-3-19',70))

mar22 = 'Brussels bombings'
ax.annotate(mar22, xytext=('2016-3-22', 400), rotation=85,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-3-22', 185))

mar25 = 'Aden car bombing'
ax.annotate(mar25, xytext=('2016-3-25', 650), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-3-25', 490))

mar25 = 'Iraqi soccer stadium bombings'
ax.annotate(mar25, xytext=('2016-3-25', 640), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-3-25', 400))

apr25 = 'LGBT activists killed in Bangladesh'
ax.annotate(apr25, xytext=('2016-4-25', 600), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-4-25', 210))

apr30 = 'Baghdad bombing'
ax.annotate(apr30, xytext=('2016-4-30', 530), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-4-30', 170))

may01 = 'Samawa bombing'
ax.annotate(may01, xytext=('2016-5-1', 460), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-5-1', 130))

may12 = 'Bagdad bombing'
ax.annotate(may12, xytext=('2016-5-12', 610), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-5-12', 450))

may13 = 'Real Madrid fanclub massacre'
ax.annotate(may13, xytext=('2016-5-13', 610), rotation=45,
            arrowprops=dict(connectionstyle="arc3"), xy=('2016-5-13', 230))

ax.set_ylim(0,700)
plt.title('Tweets per Day and major ISIS terror attacks in March to May 2016')
plt.show()
